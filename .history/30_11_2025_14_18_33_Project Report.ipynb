# %% [markdown]
# # Data Science Project: Project Final Report

# %% [markdown]
# ## Introduction:

# %% [markdown]
# ## Methods & Results:

# %% [markdown]
# ### Set up and intro to data: "TODO should rename later."

# %% [markdown]
# ### Training and Analysis:

# %% [markdown]
# ### Player Type Exploration

# %% [markdown]
# ## Discussion:
